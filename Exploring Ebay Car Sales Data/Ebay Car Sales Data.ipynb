# %% [markdown]
# ## Ebay Car Sales Data
#
# > Introduction

# %%
import pandas as pd

# %%
autos = pd.read_csv('autos.csv', encoding='Latin-1')

# %%
autos
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8      2016-03-22 16:51:34                                         Seat_Arosa
# 9      2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10     2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# ...

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
# dateCrawled            50000 non-null object
# name                   50000 non-null object
# seller                 50000 non-null object
# offerType              50000 non-null object
# price                  50000 non-null object
# abtest                 50000 non-null object
# vehicleType            44905 non-null object
# yearOfRegistration     50000 non-null int64
# gearbox                47320 non-null object
# powerPS                50000 non-null int64
# model                  47242 non-null object
# odometer               50000 non-null object
# monthOfRegistration    50000 non-null int64
# fuelType               45518 non-null object
# brand                  50000 non-null object
# notRepairedDamage      40171 non-null object
# dateCreated            50000 non-null object
# nrOfPictures           50000 non-null int64
# ...

# %% [markdown]
# The above cwll shows there are 5000 rows and 20 columns.
# Some of the columns have missing values.
# 15 columns have an object data type and 5 columns have integer

# %%
autos.head()
# Out:
#            dateCrawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offerType   price   abtest vehicleType  yearOfRegistration  \
# 0  privat   Angebot  $5,000  control         bus                2004
# 1  privat   Angebot  $8,500  control   limousine                1997
# 2  privat   Angebot  $8,990     test   limousine                2009
# 3  privat   Angebot  $4,350  control  kleinwagen                2007
# 4  privat   Angebot  $1,350     test       kombi                2003
#
#      gearbox  powerPS   model   odometer  monthOfRegistration fuelType  \
# ...

# %%
autos.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'odometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
autos.columns = ['date_crawled', 'name', 'seller', 'offer_type', 'price', 'ab_test',
       'vehicle_type', 'registration_year', 'gearbox', 'power_ps', 'model',
       'odometer', 'registration_month', 'fuel_type', 'brand',
       'unrepaired_damage', 'date_created', 'no_of_ad_pictures', 'postal_code',
       'last_seen']

# %% [markdown]
# In the cell above i renamed the columns from camelcase to snakecase and use more descriptive names for better understanding

# %%
autos.head()
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offer_type   price  ab_test vehicle_type  registration_year  \
# 0  privat    Angebot  $5,000  control          bus               2004
# 1  privat    Angebot  $8,500  control    limousine               1997
# 2  privat    Angebot  $8,990     test    limousine               2009
# 3  privat    Angebot  $4,350  control   kleinwagen               2007
# 4  privat    Angebot  $1,350     test        kombi               2003
#
#      gearbox  power_ps   model   odometer  registration_month fuel_type  \
# ...

# %%
autos.describe()
# Out:
#        registration_year      power_ps  registration_month  no_of_ad_pictures  \
# count       50000.000000  50000.000000        50000.000000            50000.0
# mean         2005.073280    116.355920            5.723360                0.0
# std           105.712813    209.216627            3.711984                0.0
# min          1000.000000      0.000000            0.000000                0.0
# 25%          1999.000000     70.000000            3.000000                0.0
# 50%          2003.000000    105.000000            6.000000                0.0
# 75%          2008.000000    150.000000            9.000000                0.0
# max          9999.000000  17700.000000           12.000000                0.0
#
#         postal_code
# count  50000.000000
# mean   50813.627300
# std    25779.747957
# min     1067.000000
# 25%    30451.000000
# 50%    49577.000000
# 75%    71540.000000
# max    99998.000000

# %%
autos.describe(include='all')
# Out:
#                date_crawled         name  seller offer_type  price ab_test  \
# count                 50000        50000   50000      50000  50000   50000
# unique                48213        38754       2          2   2357       2
# top     2016-03-21 16:37:21  Ford_Fiesta  privat    Angebot     $0    test
# freq                      3           78   49999      49999   1421   25756
# mean                    NaN          NaN     NaN        NaN    NaN     NaN
# std                     NaN          NaN     NaN        NaN    NaN     NaN
# min                     NaN          NaN     NaN        NaN    NaN     NaN
# 25%                     NaN          NaN     NaN        NaN    NaN     NaN
# 50%                     NaN          NaN     NaN        NaN    NaN     NaN
# 75%                     NaN          NaN     NaN        NaN    NaN     NaN
# max                     NaN          NaN     NaN        NaN    NaN     NaN
#
# ...

# %% [markdown]
# Some columns have mostly one value. These columns are seller and offer_type. Also  no_of_ad_picture has only zeros
#
# Price and odometer are text columns instead of numerical columns.
#
# Registration year has a max value of 9999
#
# Gearbox column, manual is spelt manuell
#
# Unrepaired damage column has nein as no and ja as yes

# %%
autos.unrepaired_damage.value_counts()
# Out:
# nein    35232
# ja       4939
# Name: unrepaired_damage, dtype: int64

# %%
autos.odometer = autos.odometer.str.replace('km','').str.replace(',','')

# %%
autos.odometer = autos.odometer.astype('int')

# %%
autos.rename({'odometer':'odometer_km'}, axis=1, inplace=True)

# %%
autos.price = autos.price.str.replace('$','').str.replace(',','')

# %%
autos.price = autos.price.astype('int')

# %%
autos.seller.value_counts()
# Out:
# privat        49999
# gewerblich        1
# Name: seller, dtype: int64

# %%
autos.no_of_ad_pictures.value_counts()
# Out:
# 0    50000
# Name: no_of_ad_pictures, dtype: int64

# %%
autos.offer_type.value_counts()
# Out:
# Angebot    49999
# Gesuch         1
# Name: offer_type, dtype: int64

# %%
autos.drop(columns=['no_of_ad_pictures', 'seller', 'offer_type'], inplace=True)

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 17 columns):
# date_crawled          50000 non-null object
# name                  50000 non-null object
# price                 50000 non-null int32
# ab_test               50000 non-null object
# vehicle_type          44905 non-null object
# registration_year     50000 non-null int64
# gearbox               47320 non-null object
# power_ps              50000 non-null int64
# model                 47242 non-null object
# odometer_km           50000 non-null int32
# registration_month    50000 non-null int64
# fuel_type             45518 non-null object
# brand                 50000 non-null object
# unrepaired_damage     40171 non-null object
# date_created          50000 non-null object
# postal_code           50000 non-null int64
# last_seen             50000 non-null object
# dtypes: int32(2), int64(4), object(11)
# memory usage: 6.1+ MB

# %%
autos.head()
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    price  ab_test vehicle_type  registration_year    gearbox  power_ps  \
# 0   5000  control          bus               2004    manuell       158
# 1   8500  control    limousine               1997  automatik       286
# 2   8990     test    limousine               2009    manuell       102
# 3   4350  control   kleinwagen               2007  automatik        71
# 4   1350     test        kombi               2003    manuell         0
#
#     model  odometer_km  registration_month fuel_type       brand  \
# ...

# %% [markdown]
# Analyzing Odometer column

# %%
autos.odometer_km.unique().shape
# Out:
# (13,)

# %%
autos.odometer_km.describe()
# Out:
# count     50000.000000
# mean     125732.700000
# std       40042.211706
# min        5000.000000
# 25%      125000.000000
# 50%      150000.000000
# 75%      150000.000000
# max      150000.000000
# Name: odometer_km, dtype: float64

# %%
autos.odometer_km.value_counts().sort_index(ascending = False)
# Out:
# 150000    32424
# 125000     5170
# 100000     2169
# 90000      1757
# 80000      1436
# 70000      1230
# 60000      1164
# 50000      1027
# 40000       819
# 30000       789
# 20000       784
# 10000       264
# 5000        967
# Name: odometer_km, dtype: int64

# %%
autos.price.value_counts().shape
# Out:
# (2357,)

# %%
autos.price.describe()
# Out:
# count    5.000000e+04
# mean     9.840044e+03
# std      4.811044e+05
# min      0.000000e+00
# 25%      1.100000e+03
# 50%      2.950000e+03
# 75%      7.200000e+03
# max      1.000000e+08
# Name: price, dtype: float64

# %%
import seaborn as sns

# %%
sns.boxplot(autos.price)

# %% [markdown]
# From the above diagram, we can see that there is an outlier in price

# %%
sns.distplot(autos.price)

# %%
autos[autos['price']>50000]['price'].count()
# Out:
# 200

# %%
200/ len(autos) * 100
# Out:
# 0.4

# %% [markdown]
# Filling 0.4% of the data with 50000 to remove outliers

# %%
autos.price.loc[autos['price']>50000] = 50000
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
autos[autos['price']>50000]
# Out:
# Empty DataFrame
# Columns: [date_crawled, name, price, ab_test, vehicle_type, registration_year, gearbox, power_ps, model, odometer_km, registration_month, fuel_type, brand, unrepaired_damage, date_created, postal_code, last_seen]
# Index: []

# %% [markdown]
# checking the distribution after filling

# %%
sns.boxplot(autos.price)

# %%
autos.price.describe()
# Out:
# count    50000.000000
# mean      5591.928560
# std       7240.141064
# min          0.000000
# 25%       1100.000000
# 50%       2950.000000
# 75%       7200.000000
# max      50000.000000
# Name: price, dtype: float64

# %%
autos.odometer_km.describe()
# Out:
# count     50000.000000
# mean     125732.700000
# std       40042.211706
# min        5000.000000
# 25%      125000.000000
# 50%      150000.000000
# 75%      150000.000000
# max      150000.000000
# Name: odometer_km, dtype: float64

# %%
sns.boxplot(autos.odometer_km)

# %% [markdown]
# Convert date columns to datetime data type

# %%
autos[['date_crawled','date_created','last_seen']][0:5]
# Out:
#           date_crawled         date_created            last_seen
# 0  2016-03-26 17:47:46  2016-03-26 00:00:00  2016-04-06 06:45:54
# 1  2016-04-04 13:38:56  2016-04-04 00:00:00  2016-04-06 14:45:08
# 2  2016-03-26 18:57:24  2016-03-26 00:00:00  2016-04-06 20:15:37
# 3  2016-03-12 16:58:10  2016-03-12 00:00:00  2016-03-15 03:16:28
# 4  2016-04-01 14:38:50  2016-04-01 00:00:00  2016-04-01 14:38:50

# %%
date_crawl = autos.date_crawled.str[:10]

# %%
date_crawl.value_counts( normalize=True, dropna=False)
# Out:
# 2016-04-03    0.03868
# 2016-03-20    0.03782
# 2016-03-21    0.03752
# 2016-03-12    0.03678
# 2016-03-14    0.03662
# 2016-04-04    0.03652
# 2016-03-07    0.03596
# 2016-04-02    0.03540
# 2016-03-19    0.03490
# 2016-03-28    0.03484
# 2016-03-29    0.03418
# 2016-03-15    0.03398
# 2016-04-01    0.03380
# 2016-03-30    0.03362
# 2016-03-08    0.03330
# 2016-03-09    0.03322
# 2016-03-22    0.03294
# 2016-03-11    0.03248
# 2016-03-26    0.03248
# 2016-03-23    0.03238
# 2016-03-10    0.03212
# 2016-03-31    0.03192
# 2016-03-25    0.03174
# 2016-03-17    0.03152
# 2016-03-27    0.03104
# 2016-03-16    0.02950
# 2016-03-24    0.02910
# 2016-03-05    0.02538
# 2016-03-13    0.01556
# 2016-03-06    0.01394
# 2016-04-05    0.01310
# 2016-03-18    0.01306
# 2016-04-06    0.00318
# 2016-04-07    0.00142
# Name: date_crawled, dtype: float64

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 17 columns):
# date_crawled          50000 non-null object
# name                  50000 non-null object
# price                 50000 non-null int32
# ab_test               50000 non-null object
# vehicle_type          44905 non-null object
# registration_year     50000 non-null int64
# gearbox               47320 non-null object
# power_ps              50000 non-null int64
# model                 47242 non-null object
# odometer_km           50000 non-null int32
# registration_month    50000 non-null int64
# fuel_type             45518 non-null object
# brand                 50000 non-null object
# unrepaired_damage     40171 non-null object
# date_created          50000 non-null object
# postal_code           50000 non-null int64
# last_seen             50000 non-null object
# dtypes: int32(2), int64(4), object(11)
# memory usage: 6.1+ MB

# %%
date_crawl.value_counts().sort_index()
# Out:
# 2016-03-05    1269
# 2016-03-06     697
# 2016-03-07    1798
# 2016-03-08    1663
# 2016-03-09    1660
# 2016-03-10    1606
# 2016-03-11    1624
# 2016-03-12    1838
# 2016-03-13     778
# 2016-03-14    1831
# 2016-03-15    1699
# 2016-03-16    1475
# 2016-03-17    1576
# 2016-03-18     653
# 2016-03-19    1745
# 2016-03-20    1891
# 2016-03-21    1875
# 2016-03-22    1646
# 2016-03-23    1619
# 2016-03-24    1455
# 2016-03-25    1587
# 2016-03-26    1624
# 2016-03-27    1552
# 2016-03-28    1742
# 2016-03-29    1709
# 2016-03-30    1681
# 2016-03-31    1595
# 2016-04-01    1690
# 2016-04-02    1770
# 2016-04-03    1934
# 2016-04-04    1826
# 2016-04-05     655
# 2016-04-06     159
# 2016-04-07      71
# Name: date_crawled, dtype: int64

# %%
cols =['date_crawled', 'date_created', 'last_seen']

# %%
for col in cols:
    autos[col] = pd.to_datetime(autos[col])

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 17 columns):
# date_crawled          50000 non-null datetime64[ns]
# name                  50000 non-null object
# price                 50000 non-null float64
# ab_test               50000 non-null object
# vehicle_type          44908 non-null object
# registration_year     50000 non-null float64
# gearbox               47322 non-null object
# power_ps              50000 non-null float64
# model                 47243 non-null object
# odometer_km           50000 non-null float64
# registration_month    50000 non-null float64
# fuel_type             45521 non-null object
# brand                 50000 non-null object
# unrepaired_damage     40175 non-null object
# date_created          50000 non-null datetime64[ns]
# postal_code           50000 non-null float64
# last_seen             50000 non-null datetime64[ns]
# dtypes: datetime64[ns](3), float64(6), object(8)
# ...

# %%
autos.registration_year.describe()
# Out:
# count    50000.000000
# mean      2006.170546
# std        140.599722
# min       1000.000000
# 25%       1999.000000
# 50%       2003.000000
# 75%       2008.000000
# max       9999.000000
# Name: registration_year, dtype: float64

# %% [markdown]
# Check for cars that have registration year less than 1900

# %%
#fill those values with 1900
autos.registration_year.loc[autos['registration_year']<1900] = 1900
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %% [markdown]
# Check for cars that have registration year greater than 2019

# %%
#fill those values with 2019
autos.registration_year.loc[autos['registration_year']>2019] = 2019

# %%
#autos.registration_year.loc[autos['registration_year']>2016].count()

# %%
autos.head()
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#     price  ab_test vehicle_type  registration_year    gearbox  power_ps  \
# 0  5000.0  control          bus             2004.0    manuell     158.0
# 1  8500.0  control    limousine             1997.0  automatik     286.0
# 2  8990.0     test    limousine             2009.0    manuell     102.0
# 3  4350.0  control   kleinwagen             2007.0  automatik      71.0
# 4  1350.0     test        kombi             2003.0    manuell       0.0
#
#     model  odometer_km  registration_month fuel_type       brand  \
# ...

# %%
autos.gearbox.replace({'manuell':'manual', 'automatik':'automatic'}, inplace=True)

# %%
autos.gearbox.value_counts()
# Out:
# manual       36993
# automatic    10327
# Name: gearbox, dtype: int64

# %%
autos.unrepaired_damage.value_counts()
# Out:
# nein    35232
# ja       4939
# Name: unrepaired_damage, dtype: int64

# %%
autos.unrepaired_damage.replace({'nein':'no', 'ja':'yes'}, inplace=True)

# %%
autos.unrepaired_damage.value_counts()
# Out:
# no     35232
# yes     4939
# Name: unrepaired_damage, dtype: int64

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 17 columns):
# date_crawled          50000 non-null datetime64[ns]
# name                  50000 non-null object
# price                 50000 non-null int32
# ab_test               50000 non-null object
# vehicle_type          44905 non-null object
# registration_year     50000 non-null int64
# gearbox               47320 non-null object
# power_ps              50000 non-null int64
# model                 47242 non-null object
# odometer_km           50000 non-null int32
# registration_month    50000 non-null int64
# fuel_type             45518 non-null object
# brand                 50000 non-null object
# unrepaired_damage     40171 non-null object
# date_created          50000 non-null datetime64[ns]
# postal_code           50000 non-null int64
# last_seen             50000 non-null datetime64[ns]
# dtypes: datetime64[ns](3), int32(2), int64(4), object(8)
# memory usage: 6.1+ MB

# %%
autos.groupby('brand')['price'].mean().sort_values(ascending=False)
# Out:
# brand
# porsche           30252.292517
# land_rover        17436.292929
# jeep              11310.481818
# jaguar            10921.961039
# mini              10392.393868
# sonstige_autos     9341.412088
# audi               8881.968480
# mercedes_benz      8241.912125
# bmw                7917.449254
# chevrolet          6409.961131
# skoda              6305.044529
# dacia              5897.736434
# kia                5707.325843
# hyundai            5316.754098
# volkswagen         5168.683166
# toyota             5097.941653
# volvo              4784.704595
# nissan             4588.879310
# seat               4219.431456
# suzuki             4038.952218
# mazda              3962.542933
# alfa_romeo         3928.364742
# honda              3889.859649
# subaru             3769.981651
# citroen            3752.724679
# ford               3612.529462
# smart              3482.971469
# mitsubishi         3314.049261
# chrysler           3286.055249
# saab               3143.700000
# ...

# %%
autos.groupby(['brand']).agg(['mean','count'])['price'].sort_values(ascending=False, by='mean')
# Out:
#                         mean  count
# brand
# porsche         30252.292517    294
# land_rover      17436.292929     99
# jeep            11310.481818    110
# jaguar          10921.961039     77
# mini            10392.393868    424
# sonstige_autos   9341.412088    546
# audi             8881.968480   4283
# mercedes_benz    8241.912125   4734
# bmw              7917.449254   5429
# chevrolet        6409.961131    283
# skoda            6305.044529    786
# dacia            5897.736434    129
# kia              5707.325843    356
# hyundai          5316.754098    488
# volkswagen       5168.683166  10687
# toyota           5097.941653    617
# volvo            4784.704595    457
# nissan           4588.879310    754
# seat             4219.431456    941
# suzuki           4038.952218    293
# mazda            3962.542933    757
# alfa_romeo       3928.364742    329
# honda            3889.859649    399
# subaru           3769.981651    109
# citroen          3752.724679    701
# ...

# %%
autos.columns
# Out:
# Index(['date_crawled', 'name', 'price', 'ab_test', 'vehicle_type',
#        'registration_year', 'gearbox', 'power_ps', 'model', 'odometer_km',
#        'registration_month', 'fuel_type', 'brand', 'unrepaired_damage',
#        'date_created', 'postal_code', 'last_seen'],
#       dtype='object')

# %%
autos.groupby(['brand']).agg(['mean','count'])['price'].sort_values(ascending=False, by='mean')
# Out:
#                         mean  count
# brand
# porsche         30252.292517    294
# land_rover      17436.292929     99
# jeep            11310.481818    110
# jaguar          10921.961039     77
# mini            10392.393868    424
# sonstige_autos   9341.412088    546
# audi             8881.968480   4283
# mercedes_benz    8241.912125   4734
# bmw              7917.449254   5429
# chevrolet        6409.961131    283
# skoda            6305.044529    786
# dacia            5897.736434    129
# kia              5707.325843    356
# hyundai          5316.754098    488
# volkswagen       5168.683166  10687
# toyota           5097.941653    617
# volvo            4784.704595    457
# nissan           4588.879310    754
# seat             4219.431456    941
# suzuki           4038.952218    293
# mazda            3962.542933    757
# alfa_romeo       3928.364742    329
# honda            3889.859649    399
# subaru           3769.981651    109
# citroen          3752.724679    701
# ...

# %%
autos.groupby(['brand']).agg(['mean','count'])['odometer_km'].sort_values(ascending=False, by='mean')
# Out:
#                          mean  count
# brand
# saab            143750.000000     80
# volvo           138632.385120    457
# rover           136449.275362     69
# chrysler        133149.171271    181
# bmw             132521.643028   5429
# alfa_romeo      131109.422492    329
# mercedes_benz   130886.142797   4734
# audi            129643.941163   4283
# opel            129298.663248   5461
# volkswagen      128955.272761  10687
# renault         128223.793677   2404
# peugeot         127352.335165   1456
# jeep            126409.090909    110
# mitsubishi      126293.103448    406
# mazda           125132.100396    757
# subaru          124449.541284    109
# ford            124131.934464   3479
# honda           123709.273183    399
# lancia          123157.894737     57
# seat            122061.636557    941
# daewoo          121708.860759     79
# jaguar          121298.701299     77
# citroen         119764.621969    701
# nissan          118978.779841    754
# ...

# %%
autos.head()
# Out:
#          date_crawled                                               name  \
# 0 2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1 2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2 2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3 2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4 2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    price  ab_test vehicle_type  registration_year    gearbox  power_ps  \
# 0   5000  control          bus               2004     manual       158
# 1   8500  control    limousine               1997  automatic       286
# 2   8990     test    limousine               2009     manual       102
# 3   4350  control   kleinwagen               2007  automatic        71
# 4   1350     test        kombi               2003     manual         0
#
#     model  odometer_km  registration_month fuel_type       brand  \
# ...

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 17 columns):
# date_crawled          50000 non-null datetime64[ns]
# name                  50000 non-null object
# price                 50000 non-null int32
# ab_test               50000 non-null object
# vehicle_type          44905 non-null object
# registration_year     50000 non-null int64
# gearbox               47320 non-null object
# power_ps              50000 non-null int64
# model                 47242 non-null object
# odometer_km           50000 non-null int32
# registration_month    50000 non-null int64
# fuel_type             45518 non-null object
# brand                 50000 non-null object
# unrepaired_damage     40171 non-null object
# date_created          50000 non-null datetime64[ns]
# postal_code           50000 non-null int64
# last_seen             50000 non-null datetime64[ns]
# dtypes: datetime64[ns](3), int32(2), int64(4), object(8)
# memory usage: 6.1+ MB
